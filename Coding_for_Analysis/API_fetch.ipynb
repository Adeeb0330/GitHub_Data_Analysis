# %% [markdown]
# ### API Request ti Fetch Data

# %%
import requests
import pandas as pd

# Your GitHub token
TOKEN = "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"

headers = {
    "Authorization": f"Bearer {TOKEN}"
}

# Loop through pages and different star ranges
star_ranges = [">5000", "1000..5000", "500..1000"]
all_repos = []

for star_range in star_ranges:
    for page in range(1, 11):  # 10 pages × 100 per page = 1000 repos per range
        url = f"https://api.github.com/search/repositories?q=stars:{star_range}&sort=stars&order=desc&per_page=100&page={page}"
        response = requests.get(url, headers=headers)
        data = response.json()
        if 'items' in data:
            all_repos.extend(data['items'])

        else:
            print("No repositories found or API limit reached")

# %%
import pandas as pd

# Convert to DataFrame
df = pd.DataFrame(all_repos)

# Save to CSV
df.to_csv("github_repos_full.csv", index=False)
print("Saved full repo data to github_repos_full.csv")
df.head(5)
# Out:
# Saved full repo data to github_repos_full.csv
#           id                           node_id                    name  \
# 0   28457823  MDEwOlJlcG9zaXRvcnkyODQ1NzgyMw==            freeCodeCamp
# 1  132750724  MDEwOlJlcG9zaXRvcnkxMzI3NTA3MjQ=        build-your-own-x
# 2   21737465  MDEwOlJlcG9zaXRvcnkyMTczNzQ2NQ==                 awesome
# 3   13491895  MDEwOlJlcG9zaXRvcnkxMzQ5MTg5NQ==  free-programming-books
# 4   54346799  MDEwOlJlcG9zaXRvcnk1NDM0Njc5OQ==             public-apis
#
#                                 full_name  private  \
# 0               freeCodeCamp/freeCodeCamp    False
# 1        codecrafters-io/build-your-own-x    False
# 2                    sindresorhus/awesome    False
# 3  EbookFoundation/free-programming-books    False
# 4                 public-apis/public-apis    False
#
#                                                owner  \
# 0  {'login': 'freeCodeCamp', 'id': 9892522, 'node...
# 1  {'login': 'codecrafters-io', 'id': 58904235, '...
# ...
